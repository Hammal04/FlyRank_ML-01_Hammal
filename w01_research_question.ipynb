# %% [markdown]
# <a href="https://colab.research.google.com/github/Hammal04/FlyRank_ML-01_Hammal/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Search Ranking & Discoverability
#
# I chose the Search Ranking & Discoverability lane because I am interested in understanding the factors that affect website visibility in search engines. By analyzing search-related data, I hope to discover patterns that can help improve search performance and support better SEO decisions using machine learning.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Research Question:
# Which webpage features are associated with better search rankings and discoverability?
#
# Decision:
# Determine which webpage characteristics should be prioritized to improve search visibility.
#
# Action:
# SEO specialists and website owners can optimize pages based on the identified factors.
#
# Cost of a Wrong Call:
# A poor recommendation may reduce website traffic, lower user engagement, and waste time and resources on ineffective SEO improvements.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\nAverage Search Volume:", round(df["search_volume"].mean(),2))
print("Average Word Count:", round(df["word_count"].mean(),2))
print("Average CTR:", round(df["ctr"].mean(),2))
# Out:
# Rows: 30000
# Columns: 44
#
# Average Search Volume: 158.88
# Average Word Count: 3107.76
# Average CTR: 0.51

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project identifies patterns and relationships in the data to support SEO decision-making. The results can help prioritize improvements, but they do not prove that one factor directly causes better search rankings. The model supports decisions based on historical data and should not be interpreted as predicting Google's ranking algorithm with certainty.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
